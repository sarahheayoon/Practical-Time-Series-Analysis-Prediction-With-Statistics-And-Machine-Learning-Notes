# %%
import numpy as np 	

def taxi_id_number(num_taxis): 
   arr = np.arange(num_taxis)
   np.random.shuffle(arr)
   for i in range(num_taxis):
       yield arr[i]

# %%
ids = taxi_id_number(10) 
print(next(ids))
print(next(ids))
print(next(ids))
# Out:
# 6
# 5
# 8

# %%
def shift_info():
   start_times_and_freqs = [(0, 8), (8, 30), (16, 15)]
   indices               = np.arange(len(start_times_and_freqs)) 
   while True:
       idx = np.random.choice(indices,p=[0.25,0.5,0.25]) 
       start = start_times_and_freqs[idx]
       yield (start[0], start[0] + 7.5, start[1])

# %%
def taxi_process(taxi_id_generator, shift_info_generator):
   taxi_id = next(taxi_id_generator)
   shift_start, shift_end, shift_mean_trips = next(shift_info_generator)
   actual_trips = round(np.random.normal(loc   = shift_mean_trips,
                                         scale = 2))
   average_trip_time = 6.5 / shift_mean_trips * 60
   # convert mean trip time to minutes
   between_events_time = 1.0 / (shift_mean_trips - 1) * 60
   # this is an efficient city where cabs are seldom unused
   time = shift_start
   yield TimePoint(taxi_id, 'start shift', time)
   deltaT = np.random.poisson(between_events_time) / 60
   time += deltaT
   for i in range(actual_trips):
       yield TimePoint(taxi_id, 'pick up ', time)
       deltaT = np.random.poisson(average_trip_time) / 60
       time += deltaT
       yield TimePoint(taxi_id, 'drop off ', time)
       deltaT = np.random.poisson(between_events_time) / 60
       time += deltaT
   deltaT = np.random.poisson(between_events_time) / 60
   time += deltaT
   yield TimePoint(taxi_id, 'end shift ', time)

# %%
from dataclasses import dataclass
@dataclass
class TimePoint:
   taxi_id: int
   name: str
   time: float

   def __lt__(self, other):
       return self.time < other.time

# %%
import queue

class Simulator:
   def __init__(self, num_taxis):
       self._time_points = queue.PriorityQueue()
       taxi_id_generator = taxi_id_number(num_taxis)
       shift_info_generator = shift_info()
       self._taxis = [taxi_process(taxi_id_generator,
                                   shift_info_generator) for
                                            i in range(num_taxis)]
       self._prepare_run()

   def _prepare_run(self): 
       for t in self._taxis:
           while True: 
               try:
                   e = next(t)
                   self._time_points.put(e)
               except:
                   break

   def run(self): 
       sim_time = 0
       while sim_time < 24:
           if self._time_points.empty():
               break
           p = self._time_points.get()
           sim_time = p.time
           print(p)

# %%
sim = Simulator(1000) 
sim.run()
# Out:
# TimePoint(taxi_id=462, name='start shift', time=0)
# TimePoint(taxi_id=802, name='start shift', time=0)
# TimePoint(taxi_id=957, name='start shift', time=0)
# TimePoint(taxi_id=116, name='start shift', time=0)
# TimePoint(taxi_id=195, name='start shift', time=0)
# TimePoint(taxi_id=649, name='start shift', time=0)
# TimePoint(taxi_id=336, name='start shift', time=0)
# TimePoint(taxi_id=972, name='start shift', time=0)
# TimePoint(taxi_id=290, name='start shift', time=0)
# TimePoint(taxi_id=242, name='start shift', time=0)
# TimePoint(taxi_id=897, name='start shift', time=0)
# TimePoint(taxi_id=189, name='start shift', time=0)
# TimePoint(taxi_id=825, name='start shift', time=0)
# TimePoint(taxi_id=252, name='start shift', time=0)
# TimePoint(taxi_id=738, name='start shift', time=0)
# TimePoint(taxi_id=176, name='start shift', time=0)
# TimePoint(taxi_id=580, name='start shift', time=0)
# TimePoint(taxi_id=681, name='start shift', time=0)
# TimePoint(taxi_id=44, name='start shift', time=0)
# TimePoint(taxi_id=636, name='start shift', time=0)
# TimePoint(taxi_id=594, name='start shift', time=0)
# TimePoint(taxi_id=772, name='start shift', time=0)
# TimePoint(taxi_id=472, name='start shift', time=0)
# TimePoint(taxi_id=817, name='start shift', time=0)
# TimePoint(taxi_id=432, name='start shift', time=0)
# TimePoint(taxi_id=526, name='start shift', time=0)
# TimePoint(taxi_id=374, name='start shift', time=0)
# TimePoint(taxi_id=329, name='start shift', time=0)
# TimePoint(taxi_id=65, name='start shift', time=0)
# TimePoint(taxi_id=282, name='start shift', time=0)
# TimePoint(taxi_id=951, name='start shift', time=0)
# TimePoint(taxi_id=160, name='start shift', time=0)
# TimePoint(taxi_id=656, name='start shift', time=0)
# TimePoint(taxi_id=126, name='start shift', time=0)
# TimePoint(taxi_id=903, name='start shift', time=0)
# TimePoint(taxi_id=105, name='start shift', time=0)
# TimePoint(taxi_id=258, name='start shift', time=0)
# TimePoint(taxi_id=554, name='start shift', time=0)
# TimePoint(taxi_id=669, name='start shift', time=0)
# TimePoint(taxi_id=994, name='start shift', time=0)
# TimePoint(taxi_id=827, name='start shift', time=0)
# TimePoint(taxi_id=660, name='start shift', time=0)
# TimePoint(taxi_id=545, name='start shift', time=0)
# TimePoint(taxi_id=227, name='start shift', time=0)
# TimePoint(taxi_id=794, name='start shift', time=0)
# TimePoint(taxi_id=46, name='start shift', time=0)
# TimePoint(taxi_id=751, name='start shift', time=0)
# TimePoint(taxi_id=781, name='start shift', time=0)
# TimePoint(taxi_id=709, name='start shift', time=0)
# TimePoint(taxi_id=350, name='start shift', time=0)
# TimePoint(taxi_id=392, name='start shift', time=0)
# TimePoint(taxi_id=699, name='start shift', time=0)
# TimePoint(taxi_id=55, name='start shift', time=0)
# TimePoint(taxi_id=201, name='start shift', time=0)
# TimePoint(taxi_id=854, name='start shift', time=0)
# TimePoint(taxi_id=63, name='start shift', time=0)
# TimePoint(taxi_id=255, name='start shift', time=0)
# TimePoint(taxi_id=632, name='start shift', time=0)
# TimePoint(taxi_id=152, name='start shift', time=0)
# TimePoint(taxi_id=45, name='start shift', time=0)
# TimePoint(taxi_id=858, name='start shift', time=0)
# TimePoint(taxi_id=372, name='start shift', time=0)
# TimePoint(taxi_id=141, name='start shift', time=0)
# TimePoint(taxi_id=22, name='start shift', time=0)
# TimePoint(taxi_id=604, name='start shift', time=0)
# TimePoint(taxi_id=459, name='start shift', time=0)
# TimePoint(taxi_id=686, name='start shift', time=0)
# TimePoint(taxi_id=835, name='start shift', time=0)
# TimePoint(taxi_id=215, name='start shift', time=0)
# TimePoint(taxi_id=312, name='start shift', time=0)
# TimePoint(taxi_id=237, name='start shift', time=0)
# TimePoint(taxi_id=789, name='start shift', time=0)
# TimePoint(taxi_id=621, name='start shift', time=0)
# TimePoint(taxi_id=521, name='start shift', time=0)
# TimePoint(taxi_id=89, name='start shift', time=0)
# TimePoint(taxi_id=10, name='start shift', time=0)
# TimePoint(taxi_id=590, name='start shift', time=0)
# TimePoint(taxi_id=531, name='start shift', time=0)
# TimePoint(taxi_id=190, name='start shift', time=0)
# TimePoint(taxi_id=248, name='start shift', time=0)
# TimePoint(taxi_id=403, name='start shift', time=0)
# TimePoint(taxi_id=973, name='start shift', time=0)
# TimePoint(taxi_id=635, name='start shift', time=0)
# TimePoint(taxi_id=14, name='start shift', time=0)
# TimePoint(taxi_id=427, name='start shift', time=0)
# TimePoint(taxi_id=828, name='start shift', time=0)
# TimePoint(taxi_id=445, name='start shift', time=0)
# TimePoint(taxi_id=164, name='start shift', time=0)
# TimePoint(taxi_id=857, name='start shift', time=0)
# TimePoint(taxi_id=790, name='start shift', time=0)
# TimePoint(taxi_id=369, name='start shift', time=0)
# TimePoint(taxi_id=960, name='start shift', time=0)
# TimePoint(taxi_id=734, name='start shift', time=0)
# TimePoint(taxi_id=570, name='start shift', time=0)
# TimePoint(taxi_id=99, name='start shift', time=0)
# TimePoint(taxi_id=998, name='start shift', time=0)
# TimePoint(taxi_id=676, name='start shift', time=0)
# TimePoint(taxi_id=743, name='start shift', time=0)
# TimePoint(taxi_id=965, name='start shift', time=0)
# TimePoint(taxi_id=496, name='start shift', time=0)
# TimePoint(taxi_id=168, name='start shift', time=0)
# TimePoint(taxi_id=845, name='start shift', time=0)
# TimePoint(taxi_id=754, name='start shift', time=0)
# TimePoint(taxi_id=180, name='start shift', time=0)
# TimePoint(taxi_id=710, name='start shift', time=0)
# TimePoint(taxi_id=473, name='start shift', time=0)
# TimePoint(taxi_id=571, name='start shift', time=0)
# TimePoint(taxi_id=125, name='start shift', time=0)
# TimePoint(taxi_id=204, name='start shift', time=0)
# TimePoint(taxi_id=982, name='start shift', time=0)
# TimePoint(taxi_id=517, name='start shift', time=0)
# TimePoint(taxi_id=659, name='start shift', time=0)
# TimePoint(taxi_id=628, name='start shift', time=0)
# TimePoint(taxi_id=585, name='start shift', time=0)
# TimePoint(taxi_id=555, name='start shift', time=0)
# TimePoint(taxi_id=77, name='start shift', time=0)
# TimePoint(taxi_id=959, name='start shift', time=0)
# TimePoint(taxi_id=393, name='start shift', time=0)
# TimePoint(taxi_id=869, name='start shift', time=0)
# TimePoint(taxi_id=8, name='start shift', time=0)
# TimePoint(taxi_id=145, name='start shift', time=0)
# TimePoint(taxi_id=411, name='start shift', time=0)
# TimePoint(taxi_id=993, name='start shift', time=0)
# TimePoint(taxi_id=294, name='start shift', time=0)
# TimePoint(taxi_id=913, name='start shift', time=0)
# TimePoint(taxi_id=4, name='start shift', time=0)
# TimePoint(taxi_id=244, name='start shift', time=0)
# TimePoint(taxi_id=397, name='start shift', time=0)
# TimePoint(taxi_id=117, name='start shift', time=0)
# TimePoint(taxi_id=495, name='start shift', time=0)
# TimePoint(taxi_id=212, name='start shift', time=0)
# TimePoint(taxi_id=214, name='start shift', time=0)
# TimePoint(taxi_id=417, name='start shift', time=0)
# TimePoint(taxi_id=380, name='start shift', time=0)
# TimePoint(taxi_id=129, name='start shift', time=0)
# TimePoint(taxi_id=624, name='start shift', time=0)
# TimePoint(taxi_id=238, name='start shift', time=0)
# TimePoint(taxi_id=48, name='start shift', time=0)
# TimePoint(taxi_id=429, name='start shift', time=0)
# TimePoint(taxi_id=884, name='start shift', time=0)
# TimePoint(taxi_id=341, name='start shift', time=0)
# TimePoint(taxi_id=103, name='start shift', time=0)
# TimePoint(taxi_id=383, name='start shift', time=0)
# TimePoint(taxi_id=688, name='start shift', time=0)
# TimePoint(taxi_id=1, name='start shift', time=0)
# TimePoint(taxi_id=156, name='start shift', time=0)
# TimePoint(taxi_id=868, name='start shift', time=0)
# TimePoint(taxi_id=298, name='start shift', time=0)
# TimePoint(taxi_id=786, name='start shift', time=0)
# TimePoint(taxi_id=87, name='start shift', time=0)
# TimePoint(taxi_id=198, name='start shift', time=0)
# TimePoint(taxi_id=127, name='start shift', time=0)
# TimePoint(taxi_id=254, name='start shift', time=0)
# TimePoint(taxi_id=933, name='start shift', time=0)
# TimePoint(taxi_id=841, name='start shift', time=0)
# TimePoint(taxi_id=989, name='start shift', time=0)
# TimePoint(taxi_id=885, name='start shift', time=0)
# TimePoint(taxi_id=151, name='start shift', time=0)
# TimePoint(taxi_id=436, name='start shift', time=0)
# TimePoint(taxi_id=906, name='start shift', time=0)
# TimePoint(taxi_id=866, name='start shift', time=0)
# TimePoint(taxi_id=524, name='start shift', time=0)
# TimePoint(taxi_id=779, name='start shift', time=0)
# TimePoint(taxi_id=376, name='start shift', time=0)
# TimePoint(taxi_id=588, name='start shift', time=0)
# TimePoint(taxi_id=136, name='start shift', time=0)
# TimePoint(taxi_id=102, name='start shift', time=0)
# TimePoint(taxi_id=150, name='start shift', time=0)
# TimePoint(taxi_id=283, name='start shift', time=0)
# TimePoint(taxi_id=848, name='start shift', time=0)
# TimePoint(taxi_id=171, name='start shift', time=0)
# TimePoint(taxi_id=390, name='start shift', time=0)
# TimePoint(taxi_id=509, name='start shift', time=0)
# TimePoint(taxi_id=893, name='start shift', time=0)
# TimePoint(taxi_id=732, name='start shift', time=0)
# TimePoint(taxi_id=673, name='start shift', time=0)
# TimePoint(taxi_id=449, name='start shift', time=0)
# TimePoint(taxi_id=388, name='start shift', time=0)
# TimePoint(taxi_id=749, name='start shift', time=0)
# TimePoint(taxi_id=454, name='start shift', time=0)
# TimePoint(taxi_id=557, name='start shift', time=0)
# TimePoint(taxi_id=266, name='start shift', time=0)
# TimePoint(taxi_id=513, name='start shift', time=0)
# TimePoint(taxi_id=645, name='start shift', time=0)
# TimePoint(taxi_id=573, name='start shift', time=0)
# TimePoint(taxi_id=927, name='start shift', time=0)
# TimePoint(taxi_id=962, name='start shift', time=0)
# TimePoint(taxi_id=373, name='start shift', time=0)
# TimePoint(taxi_id=285, name='start shift', time=0)
# TimePoint(taxi_id=363, name='start shift', time=0)
# TimePoint(taxi_id=460, name='start shift', time=0)
# TimePoint(taxi_id=59, name='start shift', time=0)
# TimePoint(taxi_id=50, name='start shift', time=0)
# TimePoint(taxi_id=923, name='start shift', time=0)
# TimePoint(taxi_id=878, name='start shift', time=0)
# TimePoint(taxi_id=948, name='start shift', time=0)
# TimePoint(taxi_id=335, name='start shift', time=0)
# TimePoint(taxi_id=728, name='start shift', time=0)
# TimePoint(taxi_id=671, name='start shift', time=0)
# TimePoint(taxi_id=476, name='start shift', time=0)
# TimePoint(taxi_id=741, name='start shift', time=0)
# TimePoint(taxi_id=703, name='start shift', time=0)
# TimePoint(taxi_id=74, name='start shift', time=0)
# TimePoint(taxi_id=905, name='start shift', time=0)
# TimePoint(taxi_id=894, name='start shift', time=0)
# TimePoint(taxi_id=409, name='start shift', time=0)
# TimePoint(taxi_id=911, name='start shift', time=0)
# TimePoint(taxi_id=977, name='start shift', time=0)
# TimePoint(taxi_id=679, name='start shift', time=0)
# TimePoint(taxi_id=834, name='start shift', time=0)
# TimePoint(taxi_id=270, name='start shift', time=0)
# TimePoint(taxi_id=352, name='start shift', time=0)
# TimePoint(taxi_id=302, name='start shift', time=0)
# TimePoint(taxi_id=501, name='start shift', time=0)
# TimePoint(taxi_id=534, name='start shift', time=0)
# TimePoint(taxi_id=620, name='start shift', time=0)
# TimePoint(taxi_id=73, name='start shift', time=0)
# TimePoint(taxi_id=37, name='start shift', time=0)
# TimePoint(taxi_id=809, name='start shift', time=0)
# TimePoint(taxi_id=243, name='start shift', time=0)
# TimePoint(taxi_id=815, name='start shift', time=0)
# TimePoint(taxi_id=208, name='start shift', time=0)
# TimePoint(taxi_id=558, name='start shift', time=0)
# TimePoint(taxi_id=135, name='start shift', time=0)
# TimePoint(taxi_id=499, name='start shift', time=0)
# TimePoint(taxi_id=441, name='start shift', time=0)
# TimePoint(taxi_id=88, name='start shift', time=0)
# TimePoint(taxi_id=20, name='start shift', time=0)
# TimePoint(taxi_id=132, name='start shift', time=0)
# TimePoint(taxi_id=384, name='start shift', time=0)
# TimePoint(taxi_id=440, name='start shift', time=0)
# TimePoint(taxi_id=904, name='start shift', time=0)
# TimePoint(taxi_id=919, name='start shift', time=0)
# TimePoint(taxi_id=549, name='start shift', time=0)
# TimePoint(taxi_id=684, name='start shift', time=0)
# TimePoint(taxi_id=109, name='start shift', time=0)
# TimePoint(taxi_id=733, name='start shift', time=0)
# TimePoint(taxi_id=493, name='start shift', time=0)
# TimePoint(taxi_id=197, name='start shift', time=0)
# TimePoint(taxi_id=209, name='start shift', time=0)
# TimePoint(taxi_id=82, name='start shift', time=0)
# TimePoint(taxi_id=220, name='start shift', time=0)
# TimePoint(taxi_id=147, name='start shift', time=0)
# TimePoint(taxi_id=224, name='start shift', time=0)
# TimePoint(taxi_id=717, name='start shift', time=0)
# TimePoint(taxi_id=30, name='start shift', time=0)
# TimePoint(taxi_id=525, name='start shift', time=0)
# TimePoint(taxi_id=646, name='start shift', time=0)
# TimePoint(taxi_id=528, name='start shift', time=0)
# TimePoint(taxi_id=181, name='start shift', time=0)
# TimePoint(taxi_id=115, name='start shift', time=0)
# TimePoint(taxi_id=527, name='start shift', time=0)
# TimePoint(taxi_id=186, name='start shift', time=0)
# TimePoint(taxi_id=76, name='start shift', time=0)
# TimePoint(taxi_id=267, name='start shift', time=0)
# TimePoint(taxi_id=715, name='start shift', time=0)
# TimePoint(taxi_id=90, name='start shift', time=0)
# TimePoint(taxi_id=908, name='start shift', time=0)
# TimePoint(taxi_id=270, name='pick up ', time=0.016666666666666666)
# TimePoint(taxi_id=126, name='pick up ', time=0.05)
# TimePoint(taxi_id=77, name='pick up ', time=0.05)
# TimePoint(taxi_id=176, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=459, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=973, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=857, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=531, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=998, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=743, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=180, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=454, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=948, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=878, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=728, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=620, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=646, name='pick up ', time=0.06666666666666667)
# TimePoint(taxi_id=336, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=897, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=22, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=215, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=14, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=828, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=676, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=473, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=628, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=380, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=441, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=809, name='pick up ', time=0.08333333333333333)
# TimePoint(taxi_id=825, name='pick up ', time=0.1)
# TimePoint(taxi_id=772, name='pick up ', time=0.1)
# TimePoint(taxi_id=432, name='pick up ', time=0.1)
# TimePoint(taxi_id=951, name='pick up ', time=0.1)
# TimePoint(taxi_id=160, name='pick up ', time=0.1)
# TimePoint(taxi_id=105, name='pick up ', time=0.1)
# TimePoint(taxi_id=141, name='pick up ', time=0.1)
# TimePoint(taxi_id=10, name='pick up ', time=0.1)
# TimePoint(taxi_id=445, name='pick up ', time=0.1)
# TimePoint(taxi_id=496, name='pick up ', time=0.1)
# TimePoint(taxi_id=156, name='pick up ', time=0.1)
# TimePoint(taxi_id=254, name='pick up ', time=0.1)
# TimePoint(taxi_id=390, name='pick up ', time=0.1)
# TimePoint(taxi_id=449, name='pick up ', time=0.1)
# TimePoint(taxi_id=815, name='pick up ', time=0.1)
# TimePoint(taxi_id=549, name='pick up ', time=0.1)
# TimePoint(taxi_id=109, name='pick up ', time=0.1)
# TimePoint(taxi_id=493, name='pick up ', time=0.1)
# TimePoint(taxi_id=30, name='pick up ', time=0.1)
# TimePoint(taxi_id=76, name='pick up ', time=0.1)
# TimePoint(taxi_id=972, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=290, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=738, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=636, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=374, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=699, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=858, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=570, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=204, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=125, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=517, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=214, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=417, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=624, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=48, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=397, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=786, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=87, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=841, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=933, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=151, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=150, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=283, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=588, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=962, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=373, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=923, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=208, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=684, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=717, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=220, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=527, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=528, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=908, name='pick up ', time=0.11666666666666667)
# TimePoint(taxi_id=189, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=282, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=994, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=669, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=545, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=751, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=802, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=201, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=237, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=635, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=790, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=590, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=734, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=965, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=659, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=8, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=585, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=869, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=411, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=4, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=244, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=884, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=688, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=383, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=1, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=436, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=906, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=171, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=732, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=927, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=363, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=645, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=524, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=50, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=703, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=894, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=679, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=74, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=302, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=834, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=209, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=224, name='pick up ', time=0.13333333333333333)
# TimePoint(taxi_id=649, name='pick up ', time=0.15)
# TimePoint(taxi_id=242, name='pick up ', time=0.15)
# TimePoint(taxi_id=44, name='pick up ', time=0.15)
# TimePoint(taxi_id=252, name='pick up ', time=0.15)
# TimePoint(taxi_id=681, name='pick up ', time=0.15)
# TimePoint(taxi_id=554, name='pick up ', time=0.15)
# TimePoint(taxi_id=903, name='pick up ', time=0.15)
# TimePoint(taxi_id=227, name='pick up ', time=0.15)
# TimePoint(taxi_id=660, name='pick up ', time=0.15)
# TimePoint(taxi_id=709, name='pick up ', time=0.15)
# TimePoint(taxi_id=350, name='pick up ', time=0.15)
# TimePoint(taxi_id=632, name='pick up ', time=0.15)
# TimePoint(taxi_id=521, name='pick up ', time=0.15)
# TimePoint(taxi_id=248, name='pick up ', time=0.15)
# TimePoint(taxi_id=427, name='pick up ', time=0.15)
# TimePoint(taxi_id=982, name='pick up ', time=0.15)
# TimePoint(taxi_id=393, name='pick up ', time=0.15)
# TimePoint(taxi_id=555, name='pick up ', time=0.15)
# TimePoint(taxi_id=993, name='pick up ', time=0.15)
# TimePoint(taxi_id=913, name='pick up ', time=0.15)
# TimePoint(taxi_id=212, name='pick up ', time=0.15)
# TimePoint(taxi_id=117, name='pick up ', time=0.15)
# TimePoint(taxi_id=429, name='pick up ', time=0.15)
# TimePoint(taxi_id=868, name='pick up ', time=0.15)
# TimePoint(taxi_id=848, name='pick up ', time=0.15)
# TimePoint(taxi_id=893, name='pick up ', time=0.15)
# TimePoint(taxi_id=779, name='pick up ', time=0.15)
# TimePoint(taxi_id=573, name='pick up ', time=0.15)
# TimePoint(taxi_id=285, name='pick up ', time=0.15)
# TimePoint(taxi_id=476, name='pick up ', time=0.15)
# TimePoint(taxi_id=911, name='pick up ', time=0.15)
# TimePoint(taxi_id=352, name='pick up ', time=0.15)
# TimePoint(taxi_id=534, name='pick up ', time=0.15)
# TimePoint(taxi_id=20, name='pick up ', time=0.15)
# TimePoint(taxi_id=132, name='pick up ', time=0.15)
# TimePoint(taxi_id=82, name='pick up ', time=0.15)
# TimePoint(taxi_id=116, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=329, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=65, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=258, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=794, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=46, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=372, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=45, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=604, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=686, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=621, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=89, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=403, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=960, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=99, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=845, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=754, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=103, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=198, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=127, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=749, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=557, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=266, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=866, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=977, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=73, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=558, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=135, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=88, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=499, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=440, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=147, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=181, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=115, name='pick up ', time=0.16666666666666666)
# TimePoint(taxi_id=580, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=472, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=55, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=255, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=63, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=312, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=789, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=164, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=710, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=571, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=959, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=145, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=341, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=509, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=37, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=904, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=197, name='pick up ', time=0.18333333333333332)
# TimePoint(taxi_id=817, name='pick up ', time=0.2)
# TimePoint(taxi_id=854, name='pick up ', time=0.2)
# TimePoint(taxi_id=152, name='pick up ', time=0.2)
# TimePoint(taxi_id=835, name='pick up ', time=0.2)
# TimePoint(taxi_id=190, name='pick up ', time=0.2)
# TimePoint(taxi_id=168, name='pick up ', time=0.2)
# TimePoint(taxi_id=294, name='pick up ', time=0.2)
# TimePoint(taxi_id=495, name='pick up ', time=0.2)
# TimePoint(taxi_id=238, name='pick up ', time=0.2)
# TimePoint(taxi_id=298, name='pick up ', time=0.2)
# TimePoint(taxi_id=885, name='pick up ', time=0.2)
# TimePoint(taxi_id=136, name='pick up ', time=0.2)
# TimePoint(taxi_id=388, name='pick up ', time=0.2)
# TimePoint(taxi_id=671, name='pick up ', time=0.2)
# TimePoint(taxi_id=409, name='pick up ', time=0.2)
# TimePoint(taxi_id=501, name='pick up ', time=0.2)
# TimePoint(taxi_id=243, name='pick up ', time=0.2)
# TimePoint(taxi_id=186, name='pick up ', time=0.2)
# TimePoint(taxi_id=195, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=526, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=781, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=129, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=460, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=335, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=919, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=384, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=733, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=715, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=90, name='pick up ', time=0.21666666666666667)
# TimePoint(taxi_id=594, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=827, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=392, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=369, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=462, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=102, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=376, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=59, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=741, name='pick up ', time=0.23333333333333334)
# TimePoint(taxi_id=989, name='pick up ', time=0.25)
# TimePoint(taxi_id=673, name='pick up ', time=0.25)
# TimePoint(taxi_id=905, name='pick up ', time=0.25)
# TimePoint(taxi_id=267, name='pick up ', time=0.25)
# TimePoint(taxi_id=656, name='pick up ', time=0.26666666666666666)
# TimePoint(taxi_id=513, name='pick up ', time=0.26666666666666666)
# TimePoint(taxi_id=957, name='pick up ', time=0.2833333333333333)
# TimePoint(taxi_id=525, name='pick up ', time=0.2833333333333333)
# TimePoint(taxi_id=282, name='drop off ', time=0.7)
# TimePoint(taxi_id=411, name='drop off ', time=0.7)
# TimePoint(taxi_id=312, name='drop off ', time=0.7000000000000001)
# TimePoint(taxi_id=48, name='drop off ', time=0.7000000000000001)
# TimePoint(taxi_id=738, name='drop off ', time=0.7166666666666667)
# TimePoint(taxi_id=77, name='drop off ', time=0.7166666666666667)
# TimePoint(taxi_id=588, name='drop off ', time=0.7166666666666667)
# TimePoint(taxi_id=390, name='drop off ', time=0.7333333333333333)
# TimePoint(taxi_id=972, name='drop off ', time=0.7333333333333334)
# TimePoint(taxi_id=473, name='drop off ', time=0.7333333333333334)
# TimePoint(taxi_id=380, name='drop off ', time=0.7333333333333334)
# TimePoint(taxi_id=857, name='drop off ', time=0.75)
# TimePoint(taxi_id=150, name='drop off ', time=0.75)
# TimePoint(taxi_id=620, name='drop off ', time=0.75)
# TimePoint(taxi_id=499, name='drop off ', time=0.75)
# TimePoint(taxi_id=454, name='drop off ', time=0.7666666666666666)
# TimePoint(taxi_id=728, name='drop off ', time=0.7666666666666666)
# TimePoint(taxi_id=373, name='drop off ', time=0.7666666666666667)
# TimePoint(taxi_id=220, name='drop off ', time=0.7666666666666667)
# TimePoint(taxi_id=772, name='drop off ', time=0.7833333333333333)
# TimePoint(taxi_id=393, name='drop off ', time=0.7833333333333333)
# TimePoint(taxi_id=198, name='drop off ', time=0.7833333333333333)
# TimePoint(taxi_id=878, name='drop off ', time=0.7999999999999999)
# TimePoint(taxi_id=74, name='drop off ', time=0.7999999999999999)
# TimePoint(taxi_id=302, name='drop off ', time=0.7999999999999999)
# TimePoint(taxi_id=781, name='drop off ', time=0.8)
# TimePoint(taxi_id=164, name='drop off ', time=0.8)
# TimePoint(taxi_id=828, name='drop off ', time=0.8)
# TimePoint(taxi_id=417, name='drop off ', time=0.8)
# TimePoint(taxi_id=87, name='drop off ', time=0.8)
# TimePoint(taxi_id=270, name='drop off ', time=0.8)
# TimePoint(taxi_id=374, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=282, name='pick up ', time=0.8166666666666667)
# TimePoint(taxi_id=77, name='pick up ', time=0.8166666666666667)
# TimePoint(taxi_id=429, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=786, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=848, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=573, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=645, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=441, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=20, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=440, name='drop off ', time=0.8166666666666667)
# TimePoint(taxi_id=965, name='drop off ', time=0.8333333333333333)
# TimePoint(taxi_id=115, name='drop off ', time=0.8333333333333333)
# TimePoint(taxi_id=897, name='drop off ', time=0.8333333333333334)
# TimePoint(taxi_id=743, name='drop off ', time=0.8333333333333334)
# TimePoint(taxi_id=204, name='drop off ', time=0.8333333333333334)
# TimePoint(taxi_id=417, name='pick up ', time=0.8333333333333334)
# TimePoint(taxi_id=588, name='pick up ', time=0.8333333333333334)
# TimePoint(taxi_id=620, name='pick up ', time=0.8333333333333334)
# TimePoint(taxi_id=809, name='drop off ', time=0.8333333333333334)
# TimePoint(taxi_id=825, name='drop off ', time=0.85)
# TimePoint(taxi_id=176, name='drop off ', time=0.85)
# TimePoint(taxi_id=45, name='drop off ', time=0.85)
# TimePoint(taxi_id=790, name='drop off ', time=0.85)
# TimePoint(taxi_id=397, name='drop off ', time=0.85)
# TimePoint(taxi_id=151, name='drop off ', time=0.85)
# TimePoint(taxi_id=645, name='pick up ', time=0.85)
# TimePoint(taxi_id=834, name='drop off ', time=0.85)
# TimePoint(taxi_id=815, name='drop off ', time=0.85)
# TimePoint(taxi_id=48, name='pick up ', time=0.8500000000000001)
# TimePoint(taxi_id=329, name='drop off ', time=0.8666666666666666)
# TimePoint(taxi_id=89, name='drop off ', time=0.8666666666666666)
# TimePoint(taxi_id=436, name='drop off ', time=0.8666666666666666)
# TimePoint(taxi_id=227, name='drop off ', time=0.8666666666666667)
# TimePoint(taxi_id=55, name='drop off ', time=0.8666666666666667)
# TimePoint(taxi_id=392, name='drop off ', time=0.8666666666666667)
# TimePoint(taxi_id=998, name='drop off ', time=0.8666666666666667)
# TimePoint(taxi_id=180, name='drop off ', time=0.8666666666666667)
# TimePoint(taxi_id=517, name='drop off ', time=0.8666666666666667)
# TimePoint(taxi_id=283, name='drop off ', time=0.8666666666666667)
# TimePoint(taxi_id=802, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=403, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=212, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=244, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=341, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=911, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=20, name='pick up ', time=0.8833333333333333)
# TimePoint(taxi_id=197, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=646, name='drop off ', time=0.8833333333333333)
# TimePoint(taxi_id=336, name='drop off ', time=0.8833333333333334)
# TimePoint(taxi_id=972, name='pick up ', time=0.8833333333333334)
# TimePoint(taxi_id=676, name='drop off ', time=0.8833333333333334)
# TimePoint(taxi_id=46, name='drop off ', time=0.8999999999999999)
# TimePoint(taxi_id=827, name='drop off ', time=0.8999999999999999)
# TimePoint(taxi_id=885, name='drop off ', time=0.8999999999999999)
# TimePoint(taxi_id=671, name='drop off ', time=0.8999999999999999)
# TimePoint(taxi_id=74, name='pick up ', time=0.8999999999999999)
# TimePoint(taxi_id=302, name='pick up ', time=0.8999999999999999)
# TimePoint(taxi_id=738, name='pick up ', time=0.9)
# TimePoint(taxi_id=772, name='pick up ', time=0.9)
# TimePoint(taxi_id=994, name='drop off ', time=0.9)
# TimePoint(taxi_id=903, name='drop off ', time=0.9)
# TimePoint(taxi_id=215, name='drop off ', time=0.9)
# TimePoint(taxi_id=125, name='drop off ', time=0.9)
# TimePoint(taxi_id=214, name='drop off ', time=0.9)
# TimePoint(taxi_id=884, name='drop off ', time=0.9)
# TimePoint(taxi_id=1, name='drop off ', time=0.9)
# TimePoint(taxi_id=87, name='pick up ', time=0.9)
# TimePoint(taxi_id=732, name='drop off ', time=0.9)
# TimePoint(taxi_id=285, name='drop off ', time=0.9)
# TimePoint(taxi_id=948, name='drop off ', time=0.9)
# TimePoint(taxi_id=904, name='drop off ', time=0.9)
# TimePoint(taxi_id=549, name='drop off ', time=0.9)
# TimePoint(taxi_id=527, name='drop off ', time=0.9)
# TimePoint(taxi_id=176, name='pick up ', time=0.9166666666666666)
# TimePoint(taxi_id=669, name='drop off ', time=0.9166666666666666)
# TimePoint(taxi_id=960, name='drop off ', time=0.9166666666666666)
# TimePoint(taxi_id=411, name='pick up ', time=0.9166666666666666)
# TimePoint(taxi_id=688, name='drop off ', time=0.9166666666666666)
# TimePoint(taxi_id=151, name='pick up ', time=0.9166666666666666)
# TimePoint(taxi_id=150, name='pick up ', time=0.9166666666666666)
# TimePoint(taxi_id=673, name='drop off ', time=0.9166666666666666)
# TimePoint(taxi_id=728, name='pick up ', time=0.9166666666666666)
# TimePoint(taxi_id=977, name='drop off ', time=0.9166666666666666)
# TimePoint(taxi_id=660, name='drop off ', time=0.9166666666666667)
# TimePoint(taxi_id=699, name='drop off ', time=0.9166666666666667)
# TimePoint(taxi_id=828, name='pick up ', time=0.9166666666666667)
# TimePoint(taxi_id=570, name='drop off ', time=0.9166666666666667)
# TimePoint(taxi_id=809, name='pick up ', time=0.9166666666666667)
# TimePoint(taxi_id=528, name='drop off ', time=0.9166666666666667)
# TimePoint(taxi_id=580, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=432, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=635, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=473, name='pick up ', time=0.9333333333333333)
# TimePoint(taxi_id=754, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=393, name='pick up ', time=0.9333333333333333)
# TimePoint(taxi_id=993, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=380, name='pick up ', time=0.9333333333333333)
# TimePoint(taxi_id=624, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=254, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=893, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=524, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=573, name='pick up ', time=0.9333333333333333)
# TimePoint(taxi_id=373, name='pick up ', time=0.9333333333333333)
# TimePoint(taxi_id=59, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=923, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=409, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=50, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=135, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=493, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=715, name='drop off ', time=0.9333333333333333)
# TimePoint(taxi_id=195, name='drop off ', time=0.95)
# TimePoint(taxi_id=189, name='drop off ', time=0.95)
# TimePoint(taxi_id=751, name='drop off ', time=0.95)
# TimePoint(taxi_id=45, name='pick up ', time=0.95)
# TimePoint(taxi_id=237, name='drop off ', time=0.95)
# TimePoint(taxi_id=496, name='drop off ', time=0.95)
# TimePoint(taxi_id=383, name='drop off ', time=0.95)
# TimePoint(taxi_id=156, name='drop off ', time=0.95)
# TimePoint(taxi_id=927, name='drop off ', time=0.95)
# TimePoint(taxi_id=878, name='pick up ', time=0.95)
# TimePoint(taxi_id=866, name='drop off ', time=0.95)
# TimePoint(taxi_id=88, name='drop off ', time=0.95)
# TimePoint(taxi_id=815, name='pick up ', time=0.95)
# TimePoint(taxi_id=919, name='drop off ', time=0.95)
# TimePoint(taxi_id=440, name='pick up ', time=0.95)
# TimePoint(taxi_id=147, name='drop off ', time=0.95)
# TimePoint(taxi_id=336, name='pick up ', time=0.9500000000000001)
# TimePoint(taxi_id=636, name='drop off ', time=0.9500000000000001)
# TimePoint(taxi_id=994, name='pick up ', time=0.9500000000000001)
# TimePoint(taxi_id=392, name='pick up ', time=0.9500000000000001)
# TimePoint(taxi_id=312, name='pick up ', time=0.9500000000000001)
# TimePoint(taxi_id=789, name='drop off ', time=0.9500000000000001)
# TimePoint(taxi_id=779, name='drop off ', time=0.9500000000000001)
# TimePoint(taxi_id=717, name='drop off ', time=0.9500000000000001)
# TimePoint(taxi_id=89, name='pick up ', time=0.9666666666666666)
# TimePoint(taxi_id=965, name='pick up ', time=0.9666666666666666)
# TimePoint(taxi_id=390, name='pick up ', time=0.9666666666666666)
# TimePoint(taxi_id=454, name='pick up ', time=0.9666666666666666)
# TimePoint(taxi_id=374, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=160, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=669, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=531, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=790, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=998, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=590, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=845, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=628, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=198, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=103, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=283, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=848, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=962, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=948, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=270, name='pick up ', time=0.9666666666666667)
# TimePoint(taxi_id=30, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=267, name='drop off ', time=0.9666666666666667)
# TimePoint(taxi_id=835, name='drop off ', time=0.9666666666666668)
# TimePoint(taxi_id=329, name='pick up ', time=0.9833333333333333)
# TimePoint(taxi_id=258, name='drop off ', time=0.9833333333333333)
# TimePoint(taxi_id=105, name='drop off ', time=0.9833333333333333)
# TimePoint(taxi_id=621, name='drop off ', time=0.9833333333333333)
# TimePoint(taxi_id=869, name='drop off ', time=0.9833333333333333)
# TimePoint(taxi_id=4, name='drop off ', time=0.9833333333333333)
# TimePoint(taxi_id=429, name='pick up ', time=0.9833333333333333)
# TimePoint(taxi_id=341, name='pick up ', time=0.9833333333333333)
# TimePoint(taxi_id=927, name='pick up ', time=0.9833333333333333)
# TimePoint(taxi_id=181, name='drop off ', time=0.9833333333333333)
# TimePoint(taxi_id=649, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=817, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=350, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=858, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=462, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=857, name='pick up ', time=0.9833333333333334)
# TimePoint(taxi_id=180, name='pick up ', time=0.9833333333333334)
# TimePoint(taxi_id=145, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=495, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=884, name='pick up ', time=0.9833333333333334)
# TimePoint(taxi_id=352, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=534, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=499, name='pick up ', time=0.9833333333333334)
# TimePoint(taxi_id=186, name='drop off ', time=0.9833333333333334)
# TimePoint(taxi_id=290, name='drop off ', time=1.0)
# TimePoint(taxi_id=126, name='drop off ', time=1.0)
# TimePoint(taxi_id=227, name='pick up ', time=1.0)
# TimePoint(taxi_id=55, name='pick up ', time=1.0)
# TimePoint(taxi_id=63, name='drop off ', time=1.0)
# TimePoint(taxi_id=22, name='drop off ', time=1.0)
# TimePoint(taxi_id=459, name='drop off ', time=1.0)
# TimePoint(taxi_id=369, name='drop off ', time=1.0)
# TimePoint(taxi_id=204, name='pick up ', time=1.0)
# TimePoint(taxi_id=517, name='pick up ', time=1.0)
# TimePoint(taxi_id=127, name='drop off ', time=1.0)
# TimePoint(taxi_id=933, name='drop off ', time=1.0)
# TimePoint(taxi_id=703, name='drop off ', time=1.0)
# TimePoint(taxi_id=834, name='pick up ', time=1.0)
# TimePoint(taxi_id=558, name='drop off ', time=1.0)
# TimePoint(taxi_id=384, name='drop off ', time=1.0)
# TimePoint(taxi_id=82, name='drop off ', time=1.0)
# TimePoint(taxi_id=527, name='pick up ', time=1.0)
# TimePoint(taxi_id=897, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=580, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=951, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=201, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=372, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=190, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=14, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=960, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=734, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=743, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=125, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=993, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=624, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=129, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=786, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=885, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=977, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=501, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=441, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=243, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=684, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=733, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=30, name='pick up ', time=1.0166666666666666)
# TimePoint(taxi_id=76, name='drop off ', time=1.0166666666666666)
# TimePoint(taxi_id=252, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=472, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=46, name='pick up ', time=1.0333333333333332)
# TimePoint(taxi_id=521, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=982, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=913, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=244, name='pick up ', time=1.0333333333333332)
# TimePoint(taxi_id=671, name='pick up ', time=1.0333333333333332)
# TimePoint(taxi_id=911, name='pick up ', time=1.0333333333333332)
# TimePoint(taxi_id=37, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=197, name='pick up ', time=1.0333333333333332)
# TimePoint(taxi_id=646, name='pick up ', time=1.0333333333333332)
# TimePoint(taxi_id=525, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=908, name='drop off ', time=1.0333333333333332)
# TimePoint(taxi_id=660, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=854, name='drop off ', time=1.0333333333333334)
# TimePoint(taxi_id=699, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=141, name='drop off ', time=1.0333333333333334)
# TimePoint(taxi_id=164, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=933, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=893, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=449, name='drop off ', time=1.0333333333333334)
# TimePoint(taxi_id=266, name='drop off ', time=1.0333333333333334)
# TimePoint(taxi_id=285, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=894, name='drop off ', time=1.0333333333333334)
# TimePoint(taxi_id=549, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=717, name='pick up ', time=1.0333333333333334)
# TimePoint(taxi_id=116, name='drop off ', time=1.05)
# TimePoint(taxi_id=258, name='pick up ', time=1.05)
# TimePoint(taxi_id=957, name='drop off ', time=1.05)
# TimePoint(taxi_id=709, name='drop off ', time=1.05)
# TimePoint(taxi_id=350, name='pick up ', time=1.05)
# TimePoint(taxi_id=255, name='drop off ', time=1.05)
# TimePoint(taxi_id=686, name='drop off ', time=1.05)
# TimePoint(taxi_id=10, name='drop off ', time=1.05)
# TimePoint(taxi_id=427, name='drop off ', time=1.05)
# TimePoint(taxi_id=570, name='pick up ', time=1.05)
# TimePoint(taxi_id=585, name='drop off ', time=1.05)
# TimePoint(taxi_id=688, name='pick up ', time=1.05)
# TimePoint(taxi_id=989, name='drop off ', time=1.05)
# TimePoint(taxi_id=102, name='drop off ', time=1.05)
# TimePoint(taxi_id=388, name='drop off ', time=1.05)
# TimePoint(taxi_id=409, name='pick up ', time=1.05)
# TimePoint(taxi_id=132, name='drop off ', time=1.05)
# TimePoint(taxi_id=220, name='pick up ', time=1.05)
# TimePoint(taxi_id=825, name='pick up ', time=1.0666666666666667)
# TimePoint(taxi_id=44, name='drop off ', time=1.0666666666666667)
# TimePoint(taxi_id=781, name='pick up ', time=1.0666666666666667)
# TimePoint(taxi_id=459, name='pick up ', time=1.0666666666666667)
# TimePoint(taxi_id=590, name='pick up ', time=1.0666666666666667)
# TimePoint(taxi_id=571, name='drop off ', time=1.0666666666666667)
# TimePoint(taxi_id=496, name='pick up ', time=1.0666666666666667)
# TimePoint(taxi_id=397, name='pick up ', time=1.0666666666666667)
# TimePoint(taxi_id=1, name='pick up ', time=1.0666666666666667)
# TimePoint(taxi_id=868, name='drop off ', time=1.0666666666666667)
# TimePoint(taxi_id=841, name='drop off ', time=1.0666666666666667)
# ...
# TimePoint(taxi_id=487, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=872, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=744, name='pick up ', time=12.633333333333338)
# TimePoint(taxi_id=446, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=274, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=698, name='pick up ', time=12.633333333333338)
# TimePoint(taxi_id=362, name='pick up ', time=12.633333333333338)
# TimePoint(taxi_id=765, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=865, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=864, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=193, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=97, name='pick up ', time=12.633333333333338)
# TimePoint(taxi_id=990, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=520, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=111, name='drop off ', time=12.633333333333338)
# TimePoint(taxi_id=446, name='pick up ', time=12.633333333333338)
# TimePoint(taxi_id=921, name='drop off ', time=12.63333333333334)
# TimePoint(taxi_id=766, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=67, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=54, name='drop off ', time=12.63333333333334)
# TimePoint(taxi_id=167, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=895, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=385, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=616, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=616, name='drop off ', time=12.63333333333334)
# TimePoint(taxi_id=455, name='drop off ', time=12.63333333333334)
# TimePoint(taxi_id=755, name='drop off ', time=12.63333333333334)
# TimePoint(taxi_id=480, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=370, name='drop off ', time=12.63333333333334)
# TimePoint(taxi_id=422, name='pick up ', time=12.63333333333334)
# TimePoint(taxi_id=19, name='drop off ', time=12.63333333333334)
# TimePoint(taxi_id=551, name='pick up ', time=12.633333333333342)
# TimePoint(taxi_id=565, name='drop off ', time=12.633333333333342)
# TimePoint(taxi_id=565, name='pick up ', time=12.633333333333342)
# TimePoint(taxi_id=16, name='pick up ', time=12.633333333333344)
# TimePoint(taxi_id=773, name='pick up ', time=12.633333333333344)
# TimePoint(taxi_id=655, name='drop off ', time=12.633333333333344)
# TimePoint(taxi_id=158, name='pick up ', time=12.633333333333344)
# TimePoint(taxi_id=170, name='pick up ', time=12.633333333333345)
# TimePoint(taxi_id=995, name='pick up ', time=12.649999999999997)
# TimePoint(taxi_id=391, name='pick up ', time=12.649999999999999)
# TimePoint(taxi_id=932, name='pick up ', time=12.649999999999999)
# TimePoint(taxi_id=999, name='pick up ', time=12.65)
# TimePoint(taxi_id=999, name='drop off ', time=12.65)
# TimePoint(taxi_id=296, name='drop off ', time=12.65)
# TimePoint(taxi_id=600, name='pick up ', time=12.65)
# TimePoint(taxi_id=627, name='pick up ', time=12.650000000000002)
# TimePoint(taxi_id=328, name='pick up ', time=12.650000000000002)
# TimePoint(taxi_id=75, name='drop off ', time=12.650000000000002)
# TimePoint(taxi_id=128, name='drop off ', time=12.650000000000002)
# TimePoint(taxi_id=40, name='pick up ', time=12.650000000000002)
# TimePoint(taxi_id=803, name='pick up ', time=12.650000000000002)
# TimePoint(taxi_id=870, name='drop off ', time=12.650000000000002)
# TimePoint(taxi_id=364, name='pick up ', time=12.650000000000002)
# TimePoint(taxi_id=364, name='drop off ', time=12.650000000000002)
# TimePoint(taxi_id=273, name='drop off ', time=12.650000000000002)
# TimePoint(taxi_id=579, name='drop off ', time=12.650000000000002)
# TimePoint(taxi_id=7, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=810, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=502, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=289, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=80, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=231, name='pick up ', time=12.650000000000004)
# TimePoint(taxi_id=377, name='pick up ', time=12.650000000000004)
# TimePoint(taxi_id=377, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=622, name='pick up ', time=12.650000000000004)
# TimePoint(taxi_id=532, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=131, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=798, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=229, name='pick up ', time=12.650000000000004)
# TimePoint(taxi_id=213, name='pick up ', time=12.650000000000004)
# TimePoint(taxi_id=56, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=614, name='drop off ', time=12.650000000000004)
# TimePoint(taxi_id=606, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=883, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=6, name='drop off ', time=12.650000000000006)
# TimePoint(taxi_id=520, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=207, name='drop off ', time=12.650000000000006)
# TimePoint(taxi_id=865, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=486, name='drop off ', time=12.650000000000006)
# TimePoint(taxi_id=276, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=864, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=990, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=337, name='pick up ', time=12.650000000000006)
# TimePoint(taxi_id=92, name='pick up ', time=12.650000000000007)
# TimePoint(taxi_id=808, name='pick up ', time=12.650000000000007)
# TimePoint(taxi_id=54, name='pick up ', time=12.650000000000007)
# TimePoint(taxi_id=537, name='pick up ', time=12.650000000000007)
# TimePoint(taxi_id=974, name='drop off ', time=12.650000000000007)
# TimePoint(taxi_id=770, name='drop off ', time=12.650000000000007)
# TimePoint(taxi_id=776, name='drop off ', time=12.650000000000007)
# TimePoint(taxi_id=925, name='pick up ', time=12.65000000000001)
# TimePoint(taxi_id=71, name='drop off ', time=12.65000000000001)
# TimePoint(taxi_id=140, name='drop off ', time=12.65000000000001)
# TimePoint(taxi_id=348, name='pick up ', time=12.65000000000001)
# TimePoint(taxi_id=901, name='pick up ', time=12.65000000000001)
# TimePoint(taxi_id=299, name='pick up ', time=12.650000000000011)
# TimePoint(taxi_id=652, name='pick up ', time=12.650000000000011)
# TimePoint(taxi_id=488, name='drop off ', time=12.666666666666666)
# TimePoint(taxi_id=401, name='drop off ', time=12.666666666666668)
# TimePoint(taxi_id=762, name='pick up ', time=12.666666666666668)
# TimePoint(taxi_id=651, name='pick up ', time=12.666666666666668)
# TimePoint(taxi_id=651, name='drop off ', time=12.666666666666668)
# TimePoint(taxi_id=288, name='drop off ', time=12.666666666666668)
# TimePoint(taxi_id=762, name='drop off ', time=12.666666666666668)
# TimePoint(taxi_id=350, name='drop off ', time=12.666666666666668)
# TimePoint(taxi_id=569, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=465, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=529, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=510, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=435, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=173, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=153, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=273, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=414, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=308, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=475, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=489, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=308, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=414, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=426, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=292, name='pick up ', time=12.66666666666667)
# TimePoint(taxi_id=603, name='drop off ', time=12.66666666666667)
# TimePoint(taxi_id=277, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=7, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=232, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=334, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=274, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=490, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=428, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=289, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=983, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=694, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=487, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=532, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=546, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=626, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=626, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=26, name='drop off ', time=12.666666666666671)
# TimePoint(taxi_id=56, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=798, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=791, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=872, name='pick up ', time=12.666666666666671)
# TimePoint(taxi_id=142, name='pick up ', time=12.666666666666673)
# TimePoint(taxi_id=42, name='pick up ', time=12.666666666666673)
# TimePoint(taxi_id=410, name='drop off ', time=12.666666666666673)
# TimePoint(taxi_id=301, name='pick up ', time=12.666666666666673)
# TimePoint(taxi_id=592, name='drop off ', time=12.666666666666673)
# TimePoint(taxi_id=755, name='pick up ', time=12.666666666666673)
# TimePoint(taxi_id=42, name='drop off ', time=12.666666666666673)
# TimePoint(taxi_id=535, name='drop off ', time=12.666666666666673)
# TimePoint(taxi_id=316, name='drop off ', time=12.666666666666673)
# TimePoint(taxi_id=31, name='drop off ', time=12.666666666666675)
# TimePoint(taxi_id=31, name='pick up ', time=12.666666666666675)
# TimePoint(taxi_id=811, name='pick up ', time=12.666666666666675)
# TimePoint(taxi_id=522, name='drop off ', time=12.666666666666675)
# TimePoint(taxi_id=770, name='pick up ', time=12.666666666666675)
# TimePoint(taxi_id=800, name='drop off ', time=12.666666666666675)
# TimePoint(taxi_id=677, name='drop off ', time=12.666666666666675)
# TimePoint(taxi_id=776, name='pick up ', time=12.666666666666675)
# TimePoint(taxi_id=654, name='pick up ', time=12.666666666666675)
# TimePoint(taxi_id=467, name='drop off ', time=12.666666666666675)
# TimePoint(taxi_id=722, name='pick up ', time=12.666666666666677)
# TimePoint(taxi_id=997, name='drop off ', time=12.683333333333334)
# TimePoint(taxi_id=261, name='drop off ', time=12.683333333333334)
# TimePoint(taxi_id=859, name='pick up ', time=12.683333333333334)
# TimePoint(taxi_id=720, name='drop off ', time=12.683333333333334)
# TimePoint(taxi_id=360, name='drop off ', time=12.683333333333334)
# TimePoint(taxi_id=575, name='drop off ', time=12.683333333333334)
# TimePoint(taxi_id=296, name='pick up ', time=12.683333333333334)
# TimePoint(taxi_id=739, name='pick up ', time=12.683333333333334)
# TimePoint(taxi_id=939, name='pick up ', time=12.683333333333335)
# TimePoint(taxi_id=416, name='drop off ', time=12.683333333333335)
# TimePoint(taxi_id=401, name='pick up ', time=12.683333333333335)
# TimePoint(taxi_id=939, name='drop off ', time=12.683333333333335)
# TimePoint(taxi_id=75, name='pick up ', time=12.683333333333335)
# TimePoint(taxi_id=757, name='drop off ', time=12.683333333333335)
# TimePoint(taxi_id=873, name='drop off ', time=12.683333333333335)
# TimePoint(taxi_id=870, name='pick up ', time=12.683333333333335)
# TimePoint(taxi_id=599, name='drop off ', time=12.683333333333335)
# TimePoint(taxi_id=128, name='pick up ', time=12.683333333333335)
# TimePoint(taxi_id=288, name='pick up ', time=12.683333333333335)
# TimePoint(taxi_id=579, name='pick up ', time=12.683333333333335)
# TimePoint(taxi_id=412, name='drop off ', time=12.683333333333335)
# TimePoint(taxi_id=680, name='drop off ', time=12.683333333333335)
# TimePoint(taxi_id=719, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=203, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=810, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=491, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=598, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=529, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=61, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=148, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=435, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=898, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=153, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=758, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=510, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=131, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=402, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=122, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=844, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=508, name='drop off ', time=12.683333333333337)
# TimePoint(taxi_id=614, name='pick up ', time=12.683333333333337)
# TimePoint(taxi_id=788, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=277, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=737, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=683, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=21, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=21, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=605, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=394, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=207, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=947, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=490, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=546, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=837, name='drop off ', time=12.683333333333339)
# TimePoint(taxi_id=193, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=232, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=788, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=111, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=6, name='pick up ', time=12.683333333333339)
# TimePoint(taxi_id=410, name='pick up ', time=12.68333333333334)
# TimePoint(taxi_id=94, name='pick up ', time=12.68333333333334)
# TimePoint(taxi_id=368, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=375, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=887, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=94, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=701, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=974, name='pick up ', time=12.68333333333334)
# TimePoint(taxi_id=12, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=305, name='pick up ', time=12.68333333333334)
# TimePoint(taxi_id=305, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=921, name='pick up ', time=12.68333333333334)
# TimePoint(taxi_id=474, name='drop off ', time=12.68333333333334)
# TimePoint(taxi_id=316, name='pick up ', time=12.68333333333334)
# TimePoint(taxi_id=550, name='drop off ', time=12.683333333333342)
# TimePoint(taxi_id=338, name='drop off ', time=12.683333333333342)
# TimePoint(taxi_id=610, name='drop off ', time=12.683333333333342)
# TimePoint(taxi_id=140, name='pick up ', time=12.683333333333342)
# TimePoint(taxi_id=467, name='pick up ', time=12.683333333333342)
# TimePoint(taxi_id=856, name='pick up ', time=12.683333333333342)
# TimePoint(taxi_id=856, name='drop off ', time=12.683333333333342)
# TimePoint(taxi_id=345, name='drop off ', time=12.683333333333342)
# TimePoint(taxi_id=610, name='pick up ', time=12.683333333333342)
# TimePoint(taxi_id=655, name='pick up ', time=12.683333333333344)
